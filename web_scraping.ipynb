# %%
import requests
from bs4 import BeautifulSoup
import csv

# Define the URL of the Wikipedia page
url = "https://en.wikipedia.org/wiki/List_of_S%26P_500_companies"

# Send an HTTP request to the URL
response = requests.get(url)

# Parse the HTML content
soup = BeautifulSoup(response.text, "html.parser")

# Find the table containing the data
table = soup.find("table", {"class": "wikitable"})

# Create a CSV file and write header row
with open("sp500_companies.csv", "w", newline="") as csv_file:
    writer = csv.writer(csv_file)
    writer.writerow(["Symbol", "Security", "GICS Sector", "GICS Sub-Industry", "Headquarters Location", "Date added", "CIK", "Founded"])

    # Iterate over each row of the table skipping the header row
    for row in table.find_all("tr")[1:]:
        # Extract data from each column of the row
        columns = row.find_all("td")
        # Check if the row has the expected number of columns
        if len(columns) == 8:
            symbol = columns[0].text.strip()
            security = columns[1].text.strip()
            gics_sector = columns[2].text.strip()
            gics_sub_industry = columns[3].text.strip()
            headquarters_location = columns[4].text.strip()
            date_added = columns[5].text.strip()
            cik = columns[6].text.strip()
            founded = columns[7].text.strip()

            # Write data to CSV file
            writer.writerow([symbol, security, gics_sector, gics_sub_industry, headquarters_location, date_added, cik, founded])

print("CSV file created successfully.")
# Out:
# CSV file created successfully.

# %%
import pandas as pd
from polygon import RESTClient

stock_symbols = []

data = pd.read_csv("sp500_companies.csv", encoding="ISO-8859-1")
for name in data['Symbol']:
    stock_symbols.append(name)
len(stock_symbols)
# Out:
# C:\Users\dimit\AppData\Local\Temp\ipykernel_3596\905245118.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd
# 503

# %%
polygon_api_key = "oYrROHUjXAjpI3X1fPpET2KUs2XnuX0G"
polygon_client  = RESTClient(polygon_api_key).vx
company = polygon_client.list_stock_financials(ticker='XOM', period_of_report_date_gt='2009-12-31')

financials_list = list(company)
financials_list
# Out:
# [StockFinancial(cik='0000034088', company_name='EXXON MOBIL CORP', end_date='2023-12-31', filing_date='2024-02-28', financials=Financials(balance_sheet={'other_noncurrent_assets': DataPoint(formula=None, label='Other Non-current Assets', order=350, unit='USD', value=17138000000.0, xpath=None), 'noncurrent_liabilities': DataPoint(formula=None, label='Noncurrent Liabilities', order=800, unit='USD', value=98463000000.0, xpath=None), 'current_assets': DataPoint(formula=None, label='Current Assets', order=200, unit='USD', value=96609000000.0, xpath=None), 'assets': DataPoint(formula=None, label='Assets', order=100, unit='USD', value=376317000000.0, xpath=None), 'equity': DataPoint(formula=None, label='Equity', order=1400, unit='USD', value=212538000000.0, xpath=None), 'liabilities': DataPoint(formula=None, label='Liabilities', order=600, unit='USD', value=163779000000.0, xpath=None), 'noncurrent_assets': DataPoint(formula=None, label='Noncurrent Assets', order=300, unit='USD', value=279708000000.0, xpath=None), 'current_liabilities': DataPoint(formula=None, label='Current Liabilities', order=700, unit='USD', value=65316000000.0, xpath=None), 'other_current_assets': DataPoint(formula=None, label='Other Current Assets', order=250, unit='USD', value=58594000000.0, xpath=None), 'liabilities_and_equity': DataPoint(formula=None, label='Liabilities And Equity', order=1900, unit='USD', value=376317000000.0, xpath=None), 'accounts_receivable': DataPoint(formula=None, label='Accounts Receivable', order=220, unit='USD', value=38015000000.0, xpath=None), 'fixed_assets': DataPoint(formula=None, label='Fixed Assets', order=320, unit='USD', value=214940000000.0, xpath=None), 'long_term_investments': DataPoint(formula=None, label='Long Term Investments', order=310, unit='USD', value=47630000000.0, xpath=None), 'equity_attributable_to_parent': DataPoint(formula=None, label='Equity Attributable To Parent', order=1600, unit='USD', value=204802000000.0, xpath=None), 'equity_attributable_to_noncontrolling_interest': DataPoint(formula=None, label='Equity Attributable To Noncontrolling Interest', order=1500, unit='USD', value=7736000000.0, xpath=None)}, cash_flow_statement=CashFlowStatement(exchange_gains_losses=ExchangeGainsLosses(formula=None, label='Exchange Gains/Losses', order=1000, unit='USD', value=105000000.0, xpath=None), net_cash_flow=NetCashFlow(formula=None, label='Net Cash Flow', order=1100, unit='USD', value=1903000000.0, xpath=None), net_cash_flow_from_financing_activities=NetCashFlowFromFinancingActivities(formula=None, label='Net Cash Flow From Financing Activities', order=700, unit='USD', value=-34297000000.0, xpath=None)), comprehensive_income=ComprehensiveIncome(comprehensive_income_loss=ComprehensiveIncomeLoss(formula=None, label='Comprehensive Income/Loss', order=100, unit='USD', value=38896000000.0, xpath=None), comprehensive_income_loss_attributable_to_parent=ComprehensiveIncomeLossAttributableToParent(formula=None, label='Comprehensive Income/Loss Attributable To Parent', order=300, unit='USD', value=37291000000.0, xpath=None), other_comprehensive_income_loss=OtherComprehensiveIncomeLoss(formula=None, label='Other Comprehensive Income/Loss', order=400, unit='USD', value=1542000000.0, xpath=None)), income_statement=IncomeStatement(basic_earnings_per_share=BasicEarningsPerShare(formula=None, label='Basic Earnings Per Share', order=4200, unit='USD / shares', value=8.89, xpath=None), cost_of_revenue=None, gross_profit=None, operating_expenses=OperatingExpenses(formula=None, label='Operating Expenses', order=1000, unit='USD', value=291799000000.0, xpath=None), revenues=Revenues(formula=None, label='Revenues', order=100, unit='USD', value=344582000000.0, xpath=None))), fiscal_period='TTM', fiscal_year='2023', source_filing_file_url='http://api.polygon.io/v1/reference/sec/filings/0000034088-24-000018/files/xom-20231231_htm.xml', source_filing_url='https://api.polygon.io/v1/reference/sec/filings/0000034088-24-000018', start_date='2023-01 ...
#  StockFinancial(cik='0000034088', company_name='EXXON MOBIL CORP', end_date='2023-12-31', filing_date=None, financials=Financials(balance_sheet={'current_liabilities': DataPoint(formula=None, label='Current Liabilities', order=700, unit='USD', value=65316000000.0, xpath=None), 'equity': DataPoint(formula=None, label='Equity', order=1400, unit='USD', value=212538000000.0, xpath=None), 'current_assets': DataPoint(formula=None, label='Current Assets', order=200, unit='USD', value=96609000000.0, xpath=None), 'noncurrent_liabilities': DataPoint(formula=None, label='Noncurrent Liabilities', order=800, unit='USD', value=98463000000.0, xpath=None), 'long_term_investments': DataPoint(formula=None, label='Long Term Investments', order=310, unit='USD', value=47630000000.0, xpath=None), 'assets': DataPoint(formula=None, label='Assets', order=100, unit='USD', value=376317000000.0, xpath=None), 'other_current_assets': DataPoint(formula=None, label='Other Current Assets', order=250, unit='USD', value=58594000000.0, xpath=None), 'accounts_receivable': DataPoint(formula=None, label='Accounts Receivable', order=220, unit='USD', value=38015000000.0, xpath=None), 'other_noncurrent_assets': DataPoint(formula=None, label='Other Non-current Assets', order=350, unit='USD', value=17138000000.0, xpath=None), 'equity_attributable_to_noncontrolling_interest': DataPoint(formula=None, label='Equity Attributable To Noncontrolling Interest', order=1500, unit='USD', value=7736000000.0, xpath=None), 'noncurrent_assets': DataPoint(formula=None, label='Noncurrent Assets', order=300, unit='USD', value=279708000000.0, xpath=None), 'equity_attributable_to_parent': DataPoint(formula=None, label='Equity Attributable To Parent', order=1600, unit='USD', value=204802000000.0, xpath=None), 'liabilities': DataPoint(formula=None, label='Liabilities', order=600, unit='USD', value=163779000000.0, xpath=None), 'liabilities_and_equity': DataPoint(formula=None, label='Liabilities And Equity', order=1900, unit='USD', value=376317000000.0, xpath=None), 'fixed_assets': DataPoint(formula=None, label='Fixed Assets', order=320, unit='USD', value=214940000000.0, xpath=None)}, cash_flow_statement=CashFlowStatement(exchange_gains_losses=ExchangeGainsLosses(formula=None, label='Exchange Gains/Losses', order=1000, unit='USD', value=182000000.0, xpath=None), net_cash_flow=NetCashFlow(formula=None, label='Net Cash Flow', order=1100, unit='USD', value=-1405000000.0, xpath=None), net_cash_flow_from_financing_activities=NetCashFlowFromFinancingActivities(formula=None, label='Net Cash Flow From Financing Activities', order=700, unit='USD', value=-9555000000.0, xpath=None)), comprehensive_income=ComprehensiveIncome(comprehensive_income_loss=ComprehensiveIncomeLoss(formula=None, label='Comprehensive Income/Loss', order=100, unit='USD', value=9185000000.0, xpath=None), comprehensive_income_loss_attributable_to_parent=ComprehensiveIncomeLossAttributableToParent(formula=None, label='Comprehensive Income/Loss Attributable To Parent', order=300, unit='USD', value=8729000000.0, xpath=None), other_comprehensive_income_loss=OtherComprehensiveIncomeLoss(formula=None, label='Other Comprehensive Income/Loss', order=400, unit='USD', value=1173000000.0, xpath=None)), income_statement=IncomeStatement(basic_earnings_per_share=BasicEarningsPerShare(formula=None, label='Basic Earnings Per Share', order=4200, unit='USD / shares', value=1.9100000000000001, xpath=None), cost_of_revenue=None, gross_profit=None, operating_expenses=OperatingExpenses(formula=None, label='Operating Expenses', order=1000, unit='USD', value=73719000000.0, xpath=None), revenues=Revenues(formula=None, label='Revenues', order=100, unit='USD', value=84344000000.0, xpath=None))), fiscal_period='Q4', fiscal_year='2023', source_filing_file_url=None, source_filing_url=None, start_date='2023-10-01'),
#  StockFinancial(cik='0000034088', company_name='EXXON MOBIL CORP', end_date='2023-12-31', filing_date='2024-02-28', financials=Financials(balance_sheet={'noncurrent_liabilities': DataPoint(formula=None, label='Noncurrent Liabilities', order=800, unit='USD', value=98463000000.0, xpath=None), 'liabilities': DataPoint(formula=None, label='Liabilities', order=600, unit='USD', value=163779000000.0, xpath=None), 'noncurrent_assets': DataPoint(formula=None, label='Noncurrent Assets', order=300, unit='USD', value=279708000000.0, xpath=None), 'equity': DataPoint(formula=None, label='Equity', order=1400, unit='USD', value=212538000000.0, xpath=None), 'current_liabilities': DataPoint(formula=None, label='Current Liabilities', order=700, unit='USD', value=65316000000.0, xpath=None), 'liabilities_and_equity': DataPoint(formula=None, label='Liabilities And Equity', order=1900, unit='USD', value=376317000000.0, xpath=None), 'long_term_investments': DataPoint(formula=None, label='Long Term Investments', order=310, unit='USD', value=47630000000.0, xpath=None), 'other_current_assets': DataPoint(formula=None, label='Other Current Assets', order=250, unit='USD', value=58594000000.0, xpath=None), 'equity_attributable_to_noncontrolling_interest': DataPoint(formula=None, label='Equity Attributable To Noncontrolling Interest', order=1500, unit='USD', value=7736000000.0, xpath=None), 'equity_attributable_to_parent': DataPoint(formula=None, label='Equity Attributable To Parent', order=1600, unit='USD', value=204802000000.0, xpath=None), 'assets': DataPoint(formula=None, label='Assets', order=100, unit='USD', value=376317000000.0, xpath=None), 'other_noncurrent_assets': DataPoint(formula=None, label='Other Non-current Assets', order=350, unit='USD', value=17138000000.0, xpath=None), 'accounts_receivable': DataPoint(formula=None, label='Accounts Receivable', order=220, unit='USD', value=38015000000.0, xpath=None), 'fixed_assets': DataPoint(formula=None, label='Fixed Assets', order=320, unit='USD', value=214940000000.0, xpath=None), 'current_assets': DataPoint(formula=None, label='Current Assets', order=200, unit='USD', value=96609000000.0, xpath=None)}, cash_flow_statement=CashFlowStatement(exchange_gains_losses=ExchangeGainsLosses(formula=None, label='Exchange Gains/Losses', order=1000, unit='USD', value=105000000.0, xpath=None), net_cash_flow=NetCashFlow(formula=None, label='Net Cash Flow', order=1100, unit='USD', value=1903000000.0, xpath=None), net_cash_flow_from_financing_activities=NetCashFlowFromFinancingActivities(formula=None, label='Net Cash Flow From Financing Activities', order=700, unit='USD', value=-34297000000.0, xpath=None)), comprehensive_income=ComprehensiveIncome(comprehensive_income_loss=ComprehensiveIncomeLoss(formula=None, label='Comprehensive Income/Loss', order=100, unit='USD', value=38896000000.0, xpath=None), comprehensive_income_loss_attributable_to_parent=ComprehensiveIncomeLossAttributableToParent(formula=None, label='Comprehensive Income/Loss Attributable To Parent', order=300, unit='USD', value=37291000000.0, xpath=None), other_comprehensive_income_loss=OtherComprehensiveIncomeLoss(formula=None, label='Other Comprehensive Income/Loss', order=400, unit='USD', value=1542000000.0, xpath=None)), income_statement=IncomeStatement(basic_earnings_per_share=BasicEarningsPerShare(formula=None, label='Basic Earnings Per Share', order=4200, unit='USD / shares', value=8.89, xpath=None), cost_of_revenue=None, gross_profit=None, operating_expenses=OperatingExpenses(formula=None, label='Operating Expenses', order=1000, unit='USD', value=291799000000.0, xpath=None), revenues=Revenues(formula=None, label='Revenues', order=100, unit='USD', value=344582000000.0, xpath=None))), fiscal_period='FY', fiscal_year='2023', source_filing_file_url='http://api.polygon.io/v1/reference/sec/filings/0000034088-24-000018/files/xom-20231231_htm.xml', source_filing_url='https://api.polygon.io/v1/reference/sec/filings/0000034088-24-000018', start_date='2023-01- ...
#  StockFinancial(cik='0000034088', company_name='EXXON MOBIL CORP', end_date='2023-09-30', filing_date='2023-10-31', financials=Financials(balance_sheet={'current_liabilities': DataPoint(formula=None, label='Current Liabilities', order=700, unit='USD', value=71186000000.0, xpath=None), 'other_current_assets': DataPoint(formula=None, label='Other Current Assets', order=250, unit='USD', value=59328000000.0, xpath=None), 'fixed_assets': DataPoint(formula=None, label='Fixed Assets', order=320, unit='USD', value=205862000000.0, xpath=None), 'equity': DataPoint(formula=None, label='Equity', order=1400, unit='USD', value=207533000000.0, xpath=None), 'current_assets': DataPoint(formula=None, label='Current Assets', order=200, unit='USD', value=101142000000.0, xpath=None), 'long_term_investments': DataPoint(formula=None, label='Long Term Investments', order=310, unit='USD', value=48066000000.0, xpath=None), 'equity_attributable_to_noncontrolling_interest': DataPoint(formula=None, label='Equity Attributable To Noncontrolling Interest', order=1500, unit='USD', value=7830000000.0, xpath=None), 'liabilities': DataPoint(formula=None, label='Liabilities', order=600, unit='USD', value=164726000000.0, xpath=None), 'accounts_receivable': DataPoint(formula=None, label='Accounts Receivable', order=220, unit='USD', value=41814000000.0, xpath=None), 'other_noncurrent_assets': DataPoint(formula=None, label='Other Non-current Assets', order=350, unit='USD', value=17189000000.0, xpath=None), 'assets': DataPoint(formula=None, label='Assets', order=100, unit='USD', value=372259000000.0, xpath=None), 'noncurrent_liabilities': DataPoint(formula=None, label='Noncurrent Liabilities', order=800, unit='USD', value=93540000000.0, xpath=None), 'liabilities_and_equity': DataPoint(formula=None, label='Liabilities And Equity', order=1900, unit='USD', value=372259000000.0, xpath=None), 'noncurrent_assets': DataPoint(formula=None, label='Noncurrent Assets', order=300, unit='USD', value=271117000000.0, xpath=None), 'equity_attributable_to_parent': DataPoint(formula=None, label='Equity Attributable To Parent', order=1600, unit='USD', value=199703000000.0, xpath=None)}, cash_flow_statement=CashFlowStatement(exchange_gains_losses=ExchangeGainsLosses(formula=None, label='Exchange Gains/Losses', order=1000, unit='USD', value=-209000000.0, xpath=None), net_cash_flow=NetCashFlow(formula=None, label='Net Cash Flow', order=1100, unit='USD', value=3416000000.0, xpath=None), net_cash_flow_from_financing_activities=NetCashFlowFromFinancingActivities(formula=None, label='Net Cash Flow From Financing Activities', order=700, unit='USD', value=-8059000000.0, xpath=None)), comprehensive_income=ComprehensiveIncome(comprehensive_income_loss=ComprehensiveIncomeLoss(formula=None, label='Comprehensive Income/Loss', order=100, unit='USD', value=8979000000.0, xpath=None), comprehensive_income_loss_attributable_to_parent=ComprehensiveIncomeLossAttributableToParent(formula=None, label='Comprehensive Income/Loss Attributable To Parent', order=300, unit='USD', value=8639000000.0, xpath=None), other_comprehensive_income_loss=OtherComprehensiveIncomeLoss(formula=None, label='Other Comprehensive Income/Loss', order=400, unit='USD', value=-367000000.0, xpath=None)), income_statement=IncomeStatement(basic_earnings_per_share=BasicEarningsPerShare(formula=None, label='Basic Earnings Per Share', order=4200, unit='USD / shares', value=2.25, xpath=None), cost_of_revenue=None, gross_profit=None, operating_expenses=OperatingExpenses(formula=None, label='Operating Expenses', order=1000, unit='USD', value=77061000000.0, xpath=None), revenues=Revenues(formula=None, label='Revenues', order=100, unit='USD', value
000.0, xpath=None), 'current_liabilities': DataPoint(formula=None, label='Current Liabilities', order=700, unit='USD', value=56363000000.0, xpath=None), 'liabilities_and_equity': DataPoint(formula=None, label='Liabilities And Equity', order=1900, unit='USD', value=332750000000.0, xpath=None)}, cash_flow_statement=CashFlowStatement(exchange_gains_losses=ExchangeGainsLosses(formula=None, label='Exchange Gains/Losses', order=1000, unit='USD', value=112000000.0, xpath=None), net_cash_flow=NetCashFlow(formula=None, label='Net Cash Flow', order=1100, unit='USD', value=-4468000000.0, xpath=None), net_cash_flow_from_financing_activities=NetCashFlowFromFinancingActivities(formula=None, label='Net Cash Flow From Financing Activities', order=700, unit='USD', value=-5283000000.0, xpath=None)), comprehensive_income=ComprehensiveIncome(comprehensive_income_loss=ComprehensiveIncomeLoss(formula=None, label='Comprehensive Income/Loss', order=100, unit='USD', value=-16880000000.0, xpath=None), comprehensive_income_loss_attributable_to_parent=ComprehensiveIncomeLossAttributableToParent(formula=None, label='Comprehensive Income/Loss Attributable To Parent', order=300, unit='USD', value=-16586000000.0, xpath=None), other_comprehensive_income_loss=OtherComprehensiveIncomeLoss(formula=None, label='Other Comprehensive Income/Loss', order=400, unit='USD', value=3723000000.0, xpath=None)), income_statement=IncomeStatement(basic_earnings_per_share=BasicEarningsPerShare(formula=None, label='Basic Earnings Per Share', order=4200, unit='USD / shares', value=-4.7, xpath=None), cost_of_revenue=None, gross_profit=None, operating_expenses=OperatingExpenses(formula=None, label='Operating Expenses', order=1000, unit='USD', value=73153000000.0, xpath=None), revenues=Revenues(formula=None, label='Revenues', order=100, unit='USD', value=46540000000.0, xpath=None))), fiscal_period='Q4', fiscal_year='2020', source_filing_file_url=None, source_filing_url=None, start_date='2020-10-01'),
#   StockFinancial(cik='0000034088', company_name='EXXON MOBIL CORP', end_date='2020-12-31', filing_date='2021-02-24', financials=Financials(balance_sheet={'equity_attributable_to_parent': DataPoint(formula=None, label='Equity Attributable To Parent', order=1600, unit='USD', value=157150000000.0, xpath=None), 'equity_attributable_to_noncontrolling_interest': DataPoint(formula=None, label='Equity Attributable To Noncontrolling Interest', order=1500, unit='USD', value=6980000000.0, xpath=None), 'other_noncurrent_assets': DataPoint(formula=None, label='Other Non-current Assets', order=350, unit='USD', value=16789000000.0, xpath=None), 'fixed_assets': DataPoint(formula=None, label='Fixed Assets', order=320, unit='USD', value=227553000000.0, xpath=None), 'liabilities': DataPoint(formula=None, label='Liabilities', order=600, unit='USD', value=168620000000.0, xpath=None), 'accounts_receivable': DataPoint(formula=None, label='Accounts Receivable', order=220, unit='USD', value=20581000000.0, xpath=None), 'noncurrent_assets': DataPoint(formula=None, label='Noncurrent Assets', order=300, unit='USD', value=287857000000.0, xpath=None), 'equity': DataPoint(formula=None, label='Equity', order=1400, unit='USD', value=164130000000.0, xpath=None), 'assets': DataPoint(formula=None, label='Assets', order=100, unit='USD', value=332750000000.0, xpath=None), 'other_current_assets': DataPoint(formula=None, label='Other Current Assets', order=250, unit='USD', value=24312000000.0, xpath=None), 'liabilities_and_equity': DataPoint(formula=None, label='Liabilities And Equity', order=1900, unit='USD', value=332750000000.0, xpath=None), 'current_liabilities': DataPoint(formula=None, label='Current Liabilities', order=700, unit='USD', value=56363000000.0, xpath=None), 'current_assets': DataPoint(formula=None, label='Current Assets', order=200, unit='USD', value=44893000000.0, xpath=None), 'noncurrent_liabilities': DataPoint(formula=None, label='Noncurrent Liabilities', order=800, unit='USD', value=112257000000.0, xpath=None), 'long_term_investments': DataPoint(formula=None, label='Long Term Investments', order=310, unit='USD', value=43515000000.0, xpath=None)}, cash_flow_statement=CashFlowStatement(exchange_gains_losses=ExchangeGainsLosses(formula=None, label='Exchange Gains/Losses', order=1000, unit='USD', value=-219000000.0, xpath=None), net_cash_flow=NetCashFlow(formula=None, label='Net Cash Flow', order=1100, unit='USD', value=1275000000.0, xpath=None), net_cash_flow_from_financing_activities=NetCashFlowFromFinancingActivities(formula=None, label='Net Cash Flow From Financing Activities', order=700, unit='USD', value=5285000000.0, xpath=None)), comprehensive_income=ComprehensiveIncome(comprehensive_income_loss=ComprehensiveIncomeLoss(formula=None, label='Comprehensive Income/Loss', order=100, unit='USD', value=-20395000000.0, xpath=None), comprehensive_income_loss_attributable_to_parent=ComprehensiveIncomeLossAttributableToParent(formula=None, label='Comprehensive Income/Loss Attributable To Parent', order=300, unit='USD', value=-19652000000.0, xpath=None), other_comprehensive_income_loss=OtherComprehensiveIncomeLoss(formula=None, label='Other Comprehensive Income/Loss', order=400, unit='USD', value=2856000000.0, xpath=None)), income_statement=IncomeStatement(basic_earnings_per_share=BasicEarningsPerShare(formula=None, label='Basic Earnings Per Share', order=4200, unit='USD / shares', value=-5.25, xpath=None), cost_of_revenue=None, gross_profit=None, operating_expenses=OperatingExpenses(formula=None, label='Operating Expenses', order=1000, unit='USD', value=210385000000.0, xpath=None), revenues=Revenues(formula=None, label='Revenues', order=100, unit='USD', value=181502000000.0, xpath=None))), fiscal_period='FY', fiscal_year='2020', source_filing_file_url='https://api.polygon.io/v1/reference/sec/filings/0000034088-21-000012/files/xom-20201231_htm.xml', source_filing_url='https://api.polygon.io/v1/reference/sec/filings/0000034088-21-000012', start_date='202 ...
# ...
#   StockFinancial(cik='0000034088', company_name='EXXON MOBIL CORP', end_date='2009-12-31', filing_date=None, financials=Financials(balance_sheet={'other_noncurrent_assets': DataPoint(formula=None, label='Other Non-current Assets', order=350, unit='USD', value=7307000000.0, xpath=None), 'assets': DataPoint(formula=None, label='Assets', order=100, unit='USD', value=233323000000.0, xpath=None), 'equity': DataPoint(formula=None, label='Equity', order=1400, unit='USD', value=115392000000.0, xpath=None), 'equity_attributable_to_parent': DataPoint(formula=None, label='Equity Attributable To Parent', order=1600, unit='USD', value=110569000000.0, xpath=None), 'long_term_investments': DataPoint(formula=None, label='Long Term Investments', order=310, unit='USD', value=31665000000.0, xpath=None), 'current_liabilities': DataPoint(formula=None, label='Current Liabilities', order=700, unit='USD', value=52061000000.0, xpath=None), 'fixed_assets': DataPoint(formula=None, label='Fixed Assets', order=320, unit='USD', value=139116000000.0, xpath=None), 'accounts_receivable': DataPoint(formula=None, label='Accounts Receivable', order=220, unit='USD', value=27645000000.0, xpath=None), 'noncurrent_assets': DataPoint(formula=None, label='Noncurrent Assets', order=300, unit='USD', value=178088000000.0, xpath=None), 'liabilities_and_equity': DataPoint(formula=None, label='Liabilities And Equity', order=1900, unit='USD', value=233323000000.0, xpath=None), 'other_current_assets': DataPoint(formula=None, label='Other Current Assets', order=250, unit='USD', value=27590000000.0, xpath=None), 'current_assets': DataPoint(formula=None, label='Current Assets', order=200, unit='USD', value=55235000000.0, xpath=None), 'liabilities': DataPoint(formula=None, label='Liabilities', order=600, unit='USD', value=117931000000.0, xpath=None), 'noncurrent_liabilities': DataPoint(formula=None, label='Noncurrent Liabilities', order=800, unit='USD', value=65870000000.0, xpath=None), 'equity_attributable_to_noncontrolling_interest': DataPoint(formula=None, label='Equity Attributable To Noncontrolling Interest', order=1500, unit='USD', value=4823000000.0, xpath=None)}, cash_flow_statement=CashFlowStatement(exchange_gains_losses=ExchangeGainsLosses(formula=None, label='Exchange Gains/Losses', order=1000, unit='USD', value=34000000.0, xpath=None), net_cash_flow=NetCashFlow(formula=None, label='Net Cash Flow', order=1100, unit='USD', value=-1779000000.0, xpath=None), net_cash_flow_from_financing_activities=NetCashFlowFromFinancingActivities(formula=None, label='Net Cash Flow From Financing Activities', order=700, unit='USD', value=-3895000000.0, xpath=None)), comprehensive_income=ComprehensiveIncome(comprehensive_income_loss=ComprehensiveIncomeLoss(formula=None, label='Comprehensive Income/Loss', order=100, unit='USD', value=10889000000.0, xpath=None), comprehensive_income_loss_attributable_to_parent=ComprehensiveIncomeLossAttributableToParent(formula=None, label='Comprehensive Income/Loss Attributable To Parent', order=300, unit='USD', value=10231000000.0, xpath=None), other_comprehensive_income_loss=OtherComprehensiveIncomeLoss(formula=None, label='Other Comprehensive Income/Loss', order=400, unit='USD', value=4750000000.0, xpath=None)), income_statement=IncomeStatement(basic_earnings_per_share=BasicEarningsPerShare(formula=None, label='Basic Earnings Per Share', order=4200, unit='USD / shares', value=1.27, xpath=None), cost_of_revenue=None, gross_profit=None, operating_expenses=None, revenues=None)), fiscal_period='Q4', fiscal_year='2009', source_filing_file_url=None, source_filing_url=None, start_date='2009-10-01'),
#   StockFinancial(cik='0000034088', company_name='EXXON MOBIL CORP', end_date='2009-12-31', filing_date='2010-02-26', financials=Financials(balance_sheet={'liabilities': DataPoint(formula=None, label='Liabilities', order=600, unit='USD', value=117931000000.0, xpath=None), 'current_liabilities': DataPoint(formula=None, label='Current Liabilities', order=700, unit='USD', value=52061000000.0, xpath=None), 'assets': DataPoint(formula=None, label='Assets', order=100, unit='USD', value=233323000000.0, xpath=None), 'equity': DataPoint(formula=None, label='Equity', order=1400, unit='USD', value=115392000000.0, xpath=None), 'other_noncurrent_assets': DataPoint(formula=None, label='Other Non-current Assets', order=350, unit='USD', value=7307000000.0, xpath=None), 'equity_attributable_to_noncontrolling_interest': DataPoint(formula=None, label='Equity Attributable To Noncontrolling Interest', order=1500, unit='USD', value=4823000000.0, xpath=None), 'noncurrent_assets': DataPoint(formula=None, label='Noncurrent Assets', order=300, unit='USD', value=178088000000.0, xpath=None), 'other_current_assets': DataPoint(formula=None, label='Other Current Assets', order=250, unit='USD', value=27590000000.0, xpath=None), 'fixed_assets': DataPoint(formula=None, label='Fixed Assets', order=320, unit='USD', value=139116000000.0, xpath=None), 'current_assets': DataPoint(formula=None, label='Current Assets', order=200, unit='USD', value=55235000000.0, xpath=None), 'long_term_investments': DataPoint(formula=None, label='Long Term Investments', order=310, unit='USD', value=31665000000.0, xpath=None), 'equity_attributable_to_parent': DataPoint(formula=None, label='Equity Attributable To Parent', order=1600, unit='USD', value=110569000000.0, xpath=None), 'accounts_receivable': DataPoint(formula=None, label='Accounts Receivable', order=220, unit='USD', value=27645000000.0, xpath=None), 'liabilities_and_equity': DataPoint(formula=None, label='Liabilities And Equity', order=1900, unit='USD', value=233323000000.0, xpath=None), 'noncurrent_liabilities': DataPoint(formula=None, label='Noncurrent Liabilities', order=800, unit='USD', value=65870000000.0, xpath=None)}, cash_flow_statement=CashFlowStatement(exchange_gains_losses=ExchangeGainsLosses(formula=None, label='Exchange Gains/Losses', order=1000, unit='USD', value=520000000.0, xpath=None), net_cash_flow=NetCashFlow(formula=None, label='Net Cash Flow', order=1100, unit='USD', value=-20744000000.0, xpath=None), net_cash_flow_from_financing_activities=NetCashFlowFromFinancingActivities(formula=None, label='Net Cash Flow From Financing Activities', order=700, unit='USD', value=-27283000000.0, xpath=None)), comprehensive_income=ComprehensiveIncome(comprehensive_income_loss=ComprehensiveIncomeLoss(formula=None, label='Comprehensive Income/Loss', order=100, unit='USD', value=24408000000.0, xpath=None), comprehensive_income_loss_attributable_to_parent=ComprehensiveIncomeLossAttributableToParent(formula=None, label='Comprehensive Income/Loss Attributable To Parent', order=300, unit='USD', value=23750000000.0, xpath=None), other_comprehensive_income_loss=OtherComprehensiveIncomeLoss(formula=None, label='Other Comprehensive Income/Loss', order=400, unit='USD', value=4750000000.0, xpath=None)), income_statement=IncomeStatement(basic_earnings_per_share=BasicEarningsPerShare(formula=None, label='Basic Earnings Per Share', order=4200, unit='USD / shares', value=3.99, xpath=None), cost_of_revenue=None, gross_profit=None, operating_expenses=None, revenues=None)), fiscal_period='FY', fiscal_year='2009', source_filing_file_url='https://api.polygon.io/v1/reference/sec/filings/0001193125-10-042929/files/xom-20091231.xml', source_filing_url='https://api.polygon.io/v1/reference/sec/filings/0001193125-10-042929', start_date='2009-01-01'),
#   StockFinancial(cik='0000034088', company_name='EXXON MOBIL CORP', end_date='2009-09-30', filing_date='2009-11-05', financials=Financials(balance_sheet={'assets': DataPoint(formula=None, label='Assets', order=100, unit='USD', value=229307000000.0, xpath=None), 'other_noncurrent_assets': DataPoint(formula=None, label='Other Non-current Assets', order=350, unit='USD', value=7045000000.0, xpath=None), 'other_current_assets': DataPoint(formula=None, label='Other Current Assets', order=250, unit='USD', value=30387000000.0, xpath=None), 'current_liabilities': DataPoint(formula=None, label='Current Liabilities', order=700, unit='USD', value=52933000000.0, xpath=None), 'equity': DataPoint(formula=None, label='Equity', order=1400, unit='USD', value=112105000000.0, xpath=None), 'liabilities': DataPoint(formula=None, label='Liabilities', order=600, unit='USD', value=117202000000.0, xpath=None), 'liabilities_and_equity': DataPoint(formula=None, label='Liabilities And Equity', order=1900, unit='USD', value=229307000000.0, xpath=None), 'equity_attributable_to_noncontrolling_interest': DataPoint(formula=None, label='Equity Attributable To Noncontrolling Interest', order=1500, unit='USD', value=4840000000.0, xpath=None), 'equity_attributable_to_parent': DataPoint(formula=None, label='Equity Attributable To Parent', order=1600, unit='USD', value=107265000000.0, xpath=None), 'fixed_assets': DataPoint(formula=None, label='Fixed Assets', order=320, unit='USD', value=132874000000.0, xpath=None), 'noncurrent_assets': DataPoint(formula=None, label='Noncurrent Assets', order=300, unit='USD', value=171983000000.0, xpath=None), 'long_term_investments': DataPoint(formula=None, label='Long Term Investments', order=310, unit='USD', value=32064000000.0, xpath=None), 'noncurrent_liabilities': DataPoint(formula=None, label='Noncurrent Liabilities', order=800, unit='USD', value=64269000000.0, xpath=None), 'accounts_receivable': DataPoint(formula=None, label='Accounts Receivable', order=220, unit='USD', value=26937000000.0, xpath=None), 'current_assets': DataPoint(formula=None, label='Current Assets', order=200, unit='USD', value=57324000000.0, xpath=None)}, cash_flow_statement=CashFlowStatement(exchange_gains_losses=ExchangeGainsLosses(formula=None, label='Exchange Gains/Losses', order=1000, unit='USD', value=381000000.0, xpath=None), net_cash_flow=NetCashFlow(formula=None, label='Net Cash Flow', order=1100, unit='USD', value=-3104000000.0, xpath=None), net_cash_flow_from_financing_activities=NetCashFlowFromFinancingActivities(formula=None, label='Net Cash Flow From Financing Activities', order=700, unit='USD', value=-6028000000.0, xpath=None)), comprehensive_income=ComprehensiveIncome(comprehensive_income_loss=ComprehensiveIncomeLoss(formula=None, label='Comprehensive Income/Loss', order=100, unit='USD', value=4871000000.0, xpath=None), comprehensive_income_loss_attributable_to_parent=ComprehensiveIncomeLossAttributableToParent(formula=None, label='Comprehensive Income/Loss Attributable To Parent', order=300, unit='USD', value=4871000000.0, xpath=None), other_comprehensive_income_loss=OtherComprehensiveIncomeLoss(formula=None, label='Other Comprehensive Income/Loss', order=400, unit='USD', value=0, xpath=None)), income_statement=IncomeStatement(basic_earnings_per_share=BasicEarningsPerShare(formula=None, label='Basic Earnings Per Share', order=4200, unit='USD / shares', value=0.98, xpath=None), cost_of_revenue=None, gross_profit=None, operating_expenses=None, revenues=None)), fiscal_period='Q3', fiscal_year='2009', source_filing_file_url='https://api.polygon.io/v1/reference/sec/filings/0001193125-09-225285/files/xom-20090930.xml', source_filing_url='https://api.polygon.io/v1/reference/sec/filings/0001193125-09-225285', start_date='2009-07-01'),
#   StockFinancial(cik='0000034088', company_name='EXXON MOBIL CORP', end_date='2009-06-30', filing_date='2009-08-05', financials=Financials(balance_sheet={'other_current_assets': DataPoint(formula=None, label='Other Current Assets', order=250, unit='USD', value=32634000000.0, xpath=None), 'liabilities': DataPoint(formula=None, label='Liabilities', order=600, unit='USD', value=113508000000.0, xpath=None), 'other_noncurrent_assets': DataPoint(formula=None, label='Other Non-current Assets', order=350, unit='USD', value=6946000000.0, xpath=None), 'accounts_receivable': DataPoint(formula=None, label='Accounts Receivable', order=220, unit='USD', value=26862000000.0, xpath=None), 'current_assets': DataPoint(formula=None, label='Current Assets', order=200, unit='USD', value=59496000000.0, xpath=None), 'equity_attributable_to_parent': DataPoint(formula=None, label='Equity Attributable To Parent', order=1600, unit='USD', value=106592000000.0, xpath=None), 'equity': DataPoint(formula=None, label='Equity', order=1400, unit='USD', value=111153000000.0, xpath=None), 'equity_attributable_to_noncontrolling_interest': DataPoint(formula=None, label='Equity Attributable To Noncontrolling Interest', order=1500, unit='USD', value=4561000000.0, xpath=None), 'current_liabilities': DataPoint(formula=None, label='Current Liabilities', order=700, unit='USD', value=51614000000.0, xpath=None), 'noncurrent_liabilities': DataPoint(formula=None, label='Noncurrent Liabilities', order=800, unit='USD', value=61894000000.0, xpath=None), 'long_term_investments': DataPoint(formula=None, label='Long Term Investments', order=310, unit='USD', value=30358000000.0, xpath=None), 'assets': DataPoint(formula=None, label='Assets', order=100, unit='USD', value=224661000000.0, xpath=None), 'fixed_assets': DataPoint(formula=None, label='Fixed Assets', order=320, unit='USD', value=127861000000.0, xpath=None), 'noncurrent_assets': DataPoint(formula=None, label='Noncurrent Assets', order=300, unit='USD', value=165165000000.0, xpath=None), 'commitments_and_contingencies': DataPoint(formula=None, label='Commitments and Contingencies', order=900, unit='USD', value=0, xpath=None), 'liabilities_and_equity': DataPoint(formula=None, label='Liabilities And Equity', order=1900, unit='USD', value=224661000000.0, xpath=None)}, cash_flow_statement=None, comprehensive_income=ComprehensiveIncome(comprehensive_income_loss=ComprehensiveIncomeLoss(formula=None, label='Comprehensive Income/Loss', order=100, unit='USD', value=3950000000.0, xpath=None), comprehensive_income_loss_attributable_to_parent=ComprehensiveIncomeLossAttributableToParent(formula=None, label='Comprehensive Income/Loss Attributable To Parent', order=300, unit='USD', value=3950000000.0, xpath=None), other_comprehensive_income_loss=OtherComprehensiveIncomeLoss(formula=None, label='Other Comprehensive Income/Loss', order=400, unit='USD', value=0, xpath=None)), income_statement=IncomeStatement(basic_earnings_per_share=BasicEarningsPerShare(formula=None, label='Basic Earnings Per Share', order=4200, unit='USD / shares', value=0.82, xpath=None), cost_of_revenue=None, gross_profit=None, operating_expenses=None, revenues=None)), fiscal_period='Q2', fiscal_year='2009', source_filing_file_url='https://api.polygon.io/v1/reference/sec/filings/0001193125-09-165196/files/xom-20090630.xml', source_filing_url='https://api.polygon.io/v1/reference/sec/filings/0001193125-09-165196', start_date='2009-04-01'),
#   StockFinancial(cik='0000034088', company_name='EXXON MOBIL CORP', end_date='2009-03-30', filing_date=None, financials=Financials(balance_sheet=None, cash_flow_statement=None, comprehensive_income=ComprehensiveIncome(comprehensive_income_loss=ComprehensiveIncomeLoss(formula=None, label='Comprehensive Income/Loss', order=100, unit='USD', value=4550000000.0, xpath=None), comprehensive_income_loss_attributable_to_parent=ComprehensiveIncomeLossAttributableToParent(formula=None, label='Comprehensive Income/Loss Attributable To Parent', order=300, unit='USD', value=4550000000.0, xpath=None), other_comprehensive_income_loss=OtherComprehensiveIncomeLoss(formula=None, label='Other Comprehensive Income/Loss', order=400, unit='USD', value=0, xpath=None)), income_statement=IncomeStatement(basic_earnings_per_share=BasicEarningsPerShare(formula=None, label='Basic Earnings Per Share', order=4200, unit='USD / shares', value=0.92, xpath=None), cost_of_revenue=None, gross_profit=None, operating_expenses=None, revenues=None)), fiscal_period='Q1', fiscal_year='2009', source_filing_file_url=None, source_filing_url=None, start_date='2009-01-01')]}

# %%
my_dict1 = {}

for financials in my_dict["XOM"]:        
    year = financials.end_date[0:4]
    if year not in my_dict1:
        my_dict1[year] = {}

    my_dict1[year][financials.end_date] = []

    my_dict1[year][financials.end_date].append(financials.financials.income_statement.revenues.value)
    my_dict1[year][financials.end_date].append(financials.financials.income_statement.gross_profit.value)
    my_dict1[year][financials.end_date].append(financials.financials.income_statement.operating_expenses.value)
    my_dict1[year][financials.end_date].append(financials.financials.income_statement.basic_earnings_per_share.value)
    print(len(my_dict[year][financials.end_date]))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[19], line 11
#       8 my_dict1[year][financials.end_date] = []
#      10 my_dict1[year][financials.end_date].append(financials.financials.income_statement.revenues.value)
# ---> 11 my_dict1[year][financials.end_date].append(financials.financials.income_statement.gross_profit.value)
#      12 my_dict1[year][financials.end_date].append(financials.financials.income_statement.operating_expenses.value)
#      13 my_dict1[year][financials.end_date].append(financials.financials.income_statement.basic_earnings_per_share.value)
#
# AttributeError: 'NoneType' object has no attribute 'value'
